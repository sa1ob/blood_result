# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
import pandas as pd

#matplotlib日本語化
import japanize_matplotlib

from matplotlib import mathtext
mathtext.FontConstantsBase = mathtext.ComputerModernFontConstants

sns.set(context="poster",style="whitegrid",font="IPAexGothic")
# %matplotlib inline
# Out:
# /home/user/.local/lib/python3.6/site-packages/japanize_matplotlib/japanize_matplotlib.py:15: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.
#   font_list = font_manager.createFontList(font_files)

# %%
csv = pd.read_csv('../jupyter/blood_c.csv',index_col=0)

# %%
csv
# Out:
#       赤血球(x10^-4)  血色素量(g/dL)  ヘマトクリット(%)  MCV(fL)  MCH(pg)  MCHC(%)  \
# day
# -11           352        11.4        32.0     90.9     32.4     35.6
# -5            338        10.7        31.1     92.0     31.7     34.4
# -3            315         9.9        28.7     91.1     31.4     34.5
# -1            328        10.2        29.3     89.3     31.1     34.8
#  1            277         8.7        24.5     88.4     31.4     35.5
#  3            289         9.0        25.0     86.5     31.1     36.0
#  6            240         7.4        20.5     85.4     30.8     36.1
#  8            157         4.8        13.3     84.7     30.6     36.1
#  13           234         7.0        19.2     82.1     29.9     36.5
#  15           257         7.7        20.9     81.3     30.0     36.8
#  17           252         7.4        20.4     81.0     29.4     36.2
#  20           275         8.4        22.6     82.2     30.5     37.2
# ...

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['白血球数(x10^-2)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([33], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[86, 86], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("白血球数$[x10^{{-}2}]$")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("白血球数$[x10^{{-}2}]$/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['赤血球(x10^-4)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([435], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[555, 555], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("赤血球数$[x10^{{-}4}]$")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("赤血球数$[x10^{{-}4}]$/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['ヘマトクリット(%)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([40.7], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[50.1,50.1], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("ヘマトクリット[%]")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("ヘマトクリット[%]/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
fig = plt.figure(figsize=(20, 15),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(3, 1, 1)
csv['MCHC(%)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([27.5], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[33.2,33.2], "blue", linestyle='dotted')
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("MCHC(%)")
plt.title("MCHC(%)/day")

ax2 = fig.add_subplot(3, 1, 2)
csv['MCV(fL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([83.6], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[98.2,98.2], "blue", linestyle='dotted')
plt.xticks(csv.index,rotation=90,fontsize=14)
ax2.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("MCV(fL)")
plt.title("MCV(fL)/day")

ax3 = fig.add_subplot(3, 1, 3)
csv['MCH(pg)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([27.5], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[33.2,33.2], "blue", linestyle='dotted')
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("MCH(pg)")
plt.title("MCH(pg)/day")
# Out:
# Text(0.5, 1.0, 'MCH(pg)/day')

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['血小板数(x10^-4)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([15.8], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[34.8,34.8], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("血小板数$[x10^{{-}4}]$")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("血小板数$[x10^{{-}4}]$/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
csv.columns
# Out:
# Index(['赤血球(x10^-4)', '血色素量(g/dL)', 'ヘマトクリット(%)', 'MCV(fL)', 'MCH(pg)',
#        'MCHC(%)', '血小板数(x10^-4)', '白血球数(x10^-2)', '杵状好中球(%)', '分葉好中球(%)',
#        'リンパ球(%)', '単球(%)', '好酸球(%)', '網赤血球数(%)', '高蛍光網赤血球比率(%)',
#        '中蛍光網赤血球比率(%)', '低蛍光網赤血球比率(%)', 'プロトンビン時間(秒)', 'PT％(秒)', 'INR(%)',
#        '活性化部分トロンボ(秒)', 'フィブリノーゲン(mg/dL)', '可溶性フィブリン(μg/mL)',
#        'トロンビンＡＴⅢ複(ng/mL)', 'Ｄ－ダイマーＦＤＰ(μg/mL)', 'ＰＩＣ(μg/mL)', 'ＰーＦＤＰ(μg/mL)',
#        '総蛋白(g/dL)', 'アルブミン(g/dL)', 'Ａ／Ｇ', '総ビリルビン(mg/dL)', '直接ビリルビン(mg/dL)',
#        '関節ビリルビン(mg/dL)', 'ＡＳＴ(U/L)', 'ＡＬＴ(U/L)', 'ＬＤＨ(U/L)', 'ＡＬＰ(U/L)',
#        'γーＧＴＰ(U/L)', 'アミラーゼ(U/L)', 'クレアチンキナーゼ(U/L)', '尿素窒素(mg/dL)',
#        'クレアチニン(mg/dL)', '尿酸(mg/dL)', 'ナトリウム(mEq/L)', 'カリウム(mEq/L)',
#        'クロール(mEq/L)', 'カルシウム(mg/dL)', 'リン(mg/dL)', 'マグネシウム(mg/dL)',
#        '血清鉄(μg/mL)', '総鉄結合能(μg/mL)', '不飽和鉄結合能(μg/mL)', '血糖(mg/dL)',
#        'Ｃ反応性蛋白(mg/dL)', 'フェリチン(ng/dL)', 'ＬＤＬ－Ｃ(mg/dL)', 'ｅＧＦＲcre(mL/min/1)',
# ...

# %%
fig = plt.figure(figsize=(20, 15),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(3, 1, 1)
csv['総ビリルビン(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([0.4], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[1.5,1.5], "blue", linestyle='dotted')
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("総ビリルビン(mg/dL)")
plt.title("総ビリルビン(mg/dL)/day")

ax2 = fig.add_subplot(3, 1, 2)
csv['直接ビリルビン(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([0], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[0.4,0.4], "blue", linestyle='dotted')
plt.xticks(csv.index,rotation=90,fontsize=14)
ax2.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("直接ビリルビン(mg/dL)")
plt.title("直接ビリルビン(mg/dL)/day")

ax3 = fig.add_subplot(3, 1, 3)
csv['関節ビリルビン(mg/dL)'].plot(marker="o")

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("間接ビリルビン(mg/dL)")
plt.title("間接ビリルビン(mg/dL)/day")
# Out:
# Text(0.5, 1.0, '間接ビリルビン(mg/dL)/day')

# %%
fig = plt.figure(figsize=(20, 10),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(2, 1, 1)
csv['ＡＳＴ(U/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([13], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[30,30], "blue", linestyle='dotted')
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("AST(U/L)")
plt.title("AST(U/L)/day")

ax2 = fig.add_subplot(2, 1, 2)
csv['ＡＬＴ(U/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([10], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[42,42], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("ALT(U/L)")
plt.title("ALT(U/L)/day")
# Out:
# Text(0.5, 1.0, 'ALT(U/L)/day')

# %%
fig = plt.figure(figsize=(20, 10),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(2, 1, 1)
csv['ＡＬＰ(U/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([106], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[322,322], "blue", linestyle='dotted')
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("ALP(U/L)")
plt.title("ALP(U/L)/day")

ax2 = fig.add_subplot(2, 1, 2)
csv['γーＧＴＰ(U/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([13], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[64,64], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("γ-GTP(U/L)")
plt.title("γ-GTP/day")
# Out:
# Text(0.5, 1.0, 'γ-GTP/day')

# %%
fig = plt.figure(figsize=(20, 10),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(2, 1, 1)
csv['総蛋白(g/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([6.6], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[8.1,8.1], "blue", linestyle='dotted')
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("総蛋白(g/dL)")
plt.title("総蛋白(g/dL)/day")

ax2 = fig.add_subplot(2, 1, 2)
csv['アルブミン(g/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([4.1], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[5.1,5.1], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("アルブミン(g/dL)")
plt.title("アルブミン(g/dL)")
# Out:
# Text(0.5, 1.0, 'アルブミン(g/dL)')

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['尿素窒素(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([8], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[20,20], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("尿素窒素(mg/dL)")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("尿素窒素(mg/dL)/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['クレアチニン(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([0.65], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[1.27,1.27], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("尿素窒素(mg/dL)")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("尿素窒素(mg/dL)/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
fig = plt.figure(figsize=(20, 15),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(3, 1, 1)
csv['尿素窒素(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([8], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[20,20], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("尿素窒素(mg/dL)")
plt.title("尿素窒素(mg/dL)/day")

ax2 = fig.add_subplot(3, 1, 2)
csv['クレアチニン(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([0.65], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[1.27,1.27], "blue", linestyle='dotted')
plt.xticks(csv.index,rotation=90,fontsize=14)
ax2.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("クレアチニン(mg/dL)")
plt.title("クレアチニン(mg/dL)/day")

ax3 = fig.add_subplot(3, 1, 3)
csv['尿酸(mg/dL)'].plot(marker="o")

plt.hlines([3.7], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[7,7], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)

plt.ylabel("尿酸(mg/dL)")
plt.title("尿酸(mg/dL)/day")
# Out:
# Text(0.5, 1.0, '尿酸(mg/dL)/day')

# %%
fig = plt.figure(figsize=(20, 20),facecolor='w', linewidth=6, edgecolor='black')
ax1 = fig.add_subplot(4, 1, 1)
csv['ナトリウム(mEq/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([138], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[145,145], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)
ax1.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.ylabel("ナトリウム(mEq/L)")
plt.title("ナトリウム(mEq/L)/day")

ax2 = fig.add_subplot(4, 1, 2)
csv['カリウム(mEq/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([3.6], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[4.8,4.8], "blue", linestyle='dotted')
plt.xticks(csv.index,rotation=90,fontsize=14)
ax2.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("カリウム(mEq/L)")
plt.title("カリウム(mEq/L)/day")

ax3 = fig.add_subplot(4, 1, 3)
csv['クロール(mEq/L)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([101], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[108,108], "blue", linestyle='dotted')
plt.xticks(csv.index,rotation=90,fontsize=14)
ax3.axes.xaxis.set_ticklabels([])
plt.xlabel("",fontsize=1)
plt.xlim(xmin-1,xmax+1)
plt.ylabel("クロール(mEq/L)")
plt.title("クロール(mEq/L)/day")


ax4 = fig.add_subplot(4, 1, 4)
csv['カルシウム(mg/dL)'].plot(marker="o")

plt.hlines([8.8], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[9.1,9.1], "blue", linestyle='dotted')

labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
labels = ax.get_xticklabels()
plt.xticks(csv.index,rotation=90,fontsize=14)
plt.xlim(xmin-1,xmax+1)

plt.ylabel("カルシウム(mg/dL)")
plt.title("カルシウム(mg/dL)/day")
# Out:
# Text(0.5, 1.0, 'カルシウム(mg/dL)/day')

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['マグネシウム(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([1.8], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[2.4,2.4], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("マグネシウム(mg/dL)")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("マグネシウム(mg/dL)/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)

# %%
fig = plt.figure(figsize=(20, 8),facecolor='w', linewidth=10, edgecolor='black')
ax = fig.add_subplot(1, 1, 1)
csv['Ｃ反応性蛋白(mg/dL)'].plot(marker="o")
xmin = min(csv.index)
xmax = max(csv.index)
plt.hlines([0], xmin-1, xmax+1, "blue", linestyles='dotted')
plt.plot([xmin-1, xmax+1],[0.14,0.14], "blue", linestyle='dotted')

plt.xlabel("day")
plt.ylabel("Ｃ反応性蛋白(mg/dL)")
plt.xticks(csv.index)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90,fontsize=16)
plt.title("Ｃ反応性蛋白(mg/dL)/day")
plt.xlim(xmin-1,xmax+1)
# Out:
# (-12.0, 103.0)
